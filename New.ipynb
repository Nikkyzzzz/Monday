# %%
# Zero or null ROI Loans
{
  "type": "Query",
  "inputs": {
    "from": "@outputs('Sample_Loan_Dump')?['body/value']",
    "where": "@and(or(equals(item()?['ASSET'],'11'), equals(item()?['ASSET'],'12')), or(equals(item()?['INT_RATE'],'0'), equals(item()?['INT_RATE'], '-')))"
  },
  "runAfter": {
    "Sample_Loan_Dump": [
      "Succeeded"
    ]
  },
  "metadata": {
    "operationMetadataId": "e17aa3be-2f11-477d-96ea-b40dbd480b20"
  }
}


# Standard accounts with URI zero
{
  "type": "Query",
  "inputs": {
    "from": "@outputs('Sample_Loan_Dump')?['body/value']",
    "where": "@and(or(equals(item()?['ASSET'],'11'), equals(item()?['ASSET'],'12')), or(equals(item()?['URI'],'0')))"
  },
  "runAfter": {
    "Sample_Loan_Dump": [
      "Succeeded"
    ]
  },
  "metadata": {
    "operationMetadataId": "d6e11a38-a107-47ca-857c-70b0e0d07260"
  }
}


# Provision Verification for Sub-Standard NPA
{
  "type": "Query",
  "inputs": {
    "from": "@outputs('Sample_Loan_Dump')?['body/value']",
    "where": "@and( equals(item()?['CUST_CATEGORY'], 'NPA'), or(equals(item()?['ASSET'], '21'), equals(item()?['ASSET'], '22')), less(div(mul(float(item()?['PROVISION']), 100), float(item()?['AMT_OS'])), 15) )"
  },
  "runAfter": {
    "Create_file": [
      "Succeeded"
    ]
  },
  "metadata": {
    "operationMetadataId": "f6717180-2514-404a-9f86-00b1e010b2e8"
  }
}


# Restructured standard accounts
{
  "type": "Query",
  "inputs": {
    "from": "@outputs('Sample_Loan_Dump')?['body/value']",
    "where": "@and( equals(item()?['RESTRUCTURED_FLG'], 'Y'), or(equals(item()?['ASSET'], '11'), equals(item()?['ASSET'], '12')), not(equals(float(item()?['AMT_OS']), 0)), less(div(mul(float(item()?['PROVISION']), 100), float(item()?['AMT_OS'])), 15), greater(int(item()?['RESTR_DATE']), variables('twoYearsAgo')))"
  },
  "runAfter": {
    "Create_file_6": [
      "Succeeded"
    ]
  },
  "metadata": {
    "operationMetadataId": "f6717180-2514-404a-9f86-00b1e010b2e8"
  }
}


# Provision Verification for Doubtful-3 NPA
{
  "type": "Query",
  "inputs": {
    "from": "@outputs('Sample_Loan_Dump')?['body/value']",
    "where": "@and(equals(item()?['CUST_CATEGORY'], 'NPA'), or(equals(item()?['ASSET'], '31'), equals(item()?['ASSET'], '32'), equals(item()?['ASSET'], '33')), not(equals(item()?['PROVISION'], item()?['AMT_OS'])))"
  },
  "runAfter": {
    "Create_file_2": [
      "Succeeded"
    ]
  },
  "metadata": {
    "operationMetadataId": "5d40ef3d-b1a6-4b9e-9b85-6a38d2f8369d"
  }
}


# NPA FB accounts with overdue flags
{
  "type": "Query",
  "inputs": {
    "from": "@outputs('Sample_Loan_Dump')?['body/value']",
    "where": "@and(equals(item()?['FB_NFB_FLG'], 'FB'), lessOrEquals(item()?['OUT_ORD_DT'], addToTime(utcNow(), -3, 'Month')))"
  },
  "runAfter": {
    "Create_file_7": [
      "Succeeded"
    ]
  },
  "metadata": {
    "operationMetadataId": "f6717180-2514-404a-9f86-00b1e010b2e8"
  }
}



# Negative Amount Outstanding
{
  "type": "Query",
  "inputs": {
    "from": "@outputs('Sample_Loan_Dump')?['body/value']",
    "where": "@less(float(item()?['AMT_OS']), 0)"
  },
  "runAfter": {
    "Create_file_3": [
      "Succeeded"
    ]
  },
  "metadata": {
    "operationMetadataId": "163c0e64-e168-4f44-aeec-cef2740966dc"
  }
}


# Standard accounts overdue details
{
  "type": "Query",
  "inputs": {
    "from": "@outputs('Sample_Loan_Dump')?['body/value']",
    "where": "@greater(sub(float(item()?['AMT_OS']), float(item()?['DRAW_LMT'])), mul(0.1, float(item()?['DRAW_LMT'])))"
  },
  "runAfter": {
    "Create_file_8": [
      "Succeeded"
    ]
  },
  "metadata": {
    "operationMetadataId": "f6717180-2514-404a-9f86-00b1e010b2e8"
  }
}


# Standard accounts with odd interest rates
{
  "type": "Query",
  "inputs": {
    "from": "@outputs('Sample_Loan_Dump')?['body/value']",
    "where": "@and(or(equals(item()?['ASSET'],'11'), equals(item()?['ASSET'],'12')), and(not(equals(item()?['INT_RATE'], '-')), not(equals(item()?['INT_RATE'], null)), not(equals(mod(float(item()?['INT_RATE']), 0.05), 0))))"
  },
  "runAfter": {
    "Create_file_9": [
      "Succeeded"
    ]
  },
  "metadata": {
    "operationMetadataId": "f6717180-2514-404a-9f86-00b1e010b2e8"
  }
}



# Agri0 sector over limit
{
  "type": "Query",
  "inputs": {
    "from": "@outputs('Sample_Loan_Dump')?['body/value']",
    "where": "@and(or(equals(item()?['ASSET'],'11'), equals(item()?['ASSET'],'12')), equals(item()?['SECTOR'],'01.Agri0'), greater(float(item()?['AMT_OS']), mul(1.34, float(item()?['SANC_LMT']))))"
  },
  "runAfter": {
    "Create_file_10": [
      "Succeeded"
    ]
  },
  "metadata": {
    "operationMetadataId": "f6717180-2514-404a-9f86-00b1e010b2e8"
  }
}

# %%
# Negative Amount Outstanding  Requires Blacklisted Pin codes

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# ---------------- 1. Zero or Null ROI Loans ---------------- # used (new version might have issues with NaN for INT_RATE)        8
def zero_or_null_roi_loans(df: pd.DataFrame) -> pd.DataFrame:
    df1 = df.copy()
    return df1[
        (df1["ASSET"].isin(["11", "12"])) &
        (df1["INT_RATE"].isin(["0", "-"]))
    ]

# ---------------- 2. Standard Accounts with URI Zero ---------------- # Same      1
def standard_accounts_with_uri_zero(df: pd.DataFrame) -> pd.DataFrame:
    df2 = df.copy()
    df2["URI"] = pd.to_numeric(df2["URI"], errors="coerce")
    return df2[(df2["ASSET"].isin(["11", "12"])) & (df2["URI"] == 0)]

# ---------------- 3. Provision Verification for Sub-Standard NPA ---------------- # used (new version has correct 15% logic)      6
def provision_verification_substandard_npa(df: pd.DataFrame) -> pd.DataFrame:
    df3 = df.copy()
    df3["PROVISION"] = pd.to_numeric(df3["PROVISION"], errors="coerce")
    df3["AMT_OS"] = pd.to_numeric(df3["AMT_OS"], errors="coerce")
    return df3[
        (df3["CUST_CATEGORY"] == "NPA") &
        (df3["ASSET"].isin(["21", "22"])) &
        ((df3["PROVISION"] * 100 / df3["AMT_OS"]) < 15)
    ]

# ---------------- 4. Restructured Standard Accounts ---------------- # Old but new insight        2
def restructured_standard_accounts(df: pd.DataFrame) -> pd.DataFrame:
    df4 = df.copy()
    df4["AMT_OS"] = pd.to_numeric(df4["AMT_OS"], errors="coerce")
    df4["PROVISION"] = pd.to_numeric(df4["PROVISION"], errors="coerce")
    df4["RESTR_DATE"] = pd.to_datetime(df4["RESTR_DATE"], errors="coerce")
    two_years_ago = datetime.today() - timedelta(days=730)

    return df4[
        (df4["RESTRUCTURED_FLG"] == "Y") &
        (df4["ASSET"].isin(["11", "12"])) &
        (df4["AMT_OS"] != 0) &
        ((df4["PROVISION"] * 100 / df4["AMT_OS"]) < 15) &
        (df4["RESTR_DATE"] > two_years_ago)
    ]

# ---------------- 5. Provision Verification for Doubtful-3 NPA ---------------- # same as previous         7
def provision_verification_doubtful3_npa(df: pd.DataFrame) -> pd.DataFrame:
    df5 = df.copy()
    df5["PROVISION"] = pd.to_numeric(df5["PROVISION"], errors="coerce")
    df5["AMT_OS"] = pd.to_numeric(df5["AMT_OS"], errors="coerce")
    return df5[
        (df5["CUST_CATEGORY"] == "NPA") &
        (df5["ASSET"].isin(["31", "32", "33"])) &
        (df5["PROVISION"] != df5["AMT_OS"])
    ]

# ---------------- 6. NPA FB Accounts with Overdue Flags ---------------- # old but new insight      4
def npa_fb_accounts_overdue(df: pd.DataFrame) -> pd.DataFrame:
    df6 = df.copy()
    df6["OUT_ORD_DT"] = pd.to_datetime(df6["OUT_ORD_DT"], errors="coerce")
    three_months_ago = datetime.today() - timedelta(days=90)
    return df6[
        (df6["FB_NFB_FLG"] == "FB") &
        (df6["OUT_ORD_DT"] <= three_months_ago)
    ]

# ---------------- 7. Negative Amount Outstanding ---------------- # same as previous    (Requires Blacklisted Pin codes)         11
def negative_amt_outstanding(df: pd.DataFrame) -> pd.DataFrame:
    df7 = df.copy()
    df7["AMT_OS"] = pd.to_numeric(df7["AMT_OS"], errors="coerce")
    return df7[df7["AMT_OS"] < 0]

# ---------------- 8. Standard Accounts Overdue Details ---------------- # same but new insight (1 step removed)         5
def standard_accounts_overdue_details(df: pd.DataFrame) -> pd.DataFrame:
    df8 = df.copy()
    df8["AMT_OS"] = pd.to_numeric(df8["AMT_OS"], errors="coerce")
    df8["DRAW_LMT"] = pd.to_numeric(df8["DRAW_LMT"], errors="coerce")
    return df8[
        (df8["AMT_OS"] - df8["DRAW_LMT"]) > (0.1 * df8["DRAW_LMT"])
    ]

# ---------------- 9. Standard Accounts with Odd Interest Rates ---------------- # same but new insight (+1 check added)       9
def standard_accounts_with_odd_interest(df: pd.DataFrame) -> pd.DataFrame:
    df9 = df.copy()
    df9["INT_RATE"] = pd.to_numeric(df9["INT_RATE"], errors="coerce")
    return df9[
        (df9["ASSET"].isin(["11", "12"])) &
        (~df9["INT_RATE"].isna()) &
        ((df9["INT_RATE"] % 0.05) != 0)
    ]

# ---------------- 10. Agri0 Sector Over Limit ---------------- # same          10
def agri0_sector_over_limit(df: pd.DataFrame) -> pd.DataFrame:
    df10 = df.copy()
    df10["AMT_OS"] = pd.to_numeric(df10["AMT_OS"], errors="coerce")
    df10["SANC_LMT"] = pd.to_numeric(df10["SANC_LMT"], errors="coerce")
    return df10[
        (df10["ASSET"].isin(["11", "12"])) &
        (df10["SECTOR"] == "01.Agri0") &
        (df10["AMT_OS"] > (1.34 * df10["SANC_LMT"]))
    ]
